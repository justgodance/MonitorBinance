# %%
#importing libraries
import time
import requests
import re
import telegram_send
import os
#from binance.p2p import Spot

# %%
pricet=[]
volumet=[]

# %%
def find_nth(text, needle, n):
    start = text.find(needle)
    while start >= 0 and n > 1:
        start = text.find(needle, start+len(needle))
        n -= 1
    return start

# %%
if os.path.exists('conf.txt')==False:
    telegram_send.configure(conf ='conf.txt' , channel=False, group=False, fm_integration=False)

# %%
telegram_send.send(messages=['Вы успешно подключились к боту'],conf='conf.txt')

# %%
def RedTink():
    headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "123",
    "content-type": "application/json",
    "Host": "p2p.binance.com",
    "Origin": "https://p2p.binance.com",
    "Pragma": "no-cache",
    "TE": "Trailers",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"
    }

    data = {
  "asset": "USDT",
  "fiat": "RUB",
  "merchantCheck": None,
  "page": 1,
  "payTypes": ["Tinkoff"],
  "publisherType": "merchant",
  "rows": 1,
  "tradeType": "SELL"
    }


    r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', headers=headers, json=data)
    kur = r.text
    index1 = find_nth(kur, 'price', 3)
    #index = find_nth(kur, 'minSingleTransAmount', 1)
    #minvalue = kur[index+23:index+33] 
    #if minvalue.find('"') == -1 :
      #  redminvaluet =float(minvalue) 
      #  print(float(minvalue))
   # else:
      #  val=minvalue.split('"',1)[0]
     #   redminvaluet = float(val)
      #  print(redminvaluet)
    redpricet=(float(kur[index1+8:index1+13]))
    return redpricet

# %%
def RedRaif():
    headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "123",
    "content-type": "application/json",
    "Host": "p2p.binance.com",
    "Origin": "https://p2p.binance.com",
    "Pragma": "no-cache",
    "TE": "Trailers",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"
    }

    data = {
  "asset": "USDT",
  "fiat": "RUB",
  "merchantCheck": None,
  "page": 1,
  "payTypes": ["RaiffeisenBankRussia"],
  "publisherType": "merchant",
  "rows": 1,
  "tradeType": "SELL"
    }


    r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', headers=headers, json=data)
    kur = r.text
    index1 = find_nth(kur, 'price', 3)
   # index = find_nth(kur, 'minSingleTransAmount', 1)
   # minvalue = kur[index+23:index+33] 
   # if minvalue.find('"') == -1 :
     #   redminvaluer =float(minvalue) 
   # else:
    #    val=minvalue.split('"',1)[0]
   #     redminvaluet = float(val)
    redpricer=(float(kur[index1+8:index1+13]))
    return redpricer

# %%
def RedSber():
    headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "123",
    "content-type": "application/json",
    "Host": "p2p.binance.com",
    "Origin": "https://p2p.binance.com",
    "Pragma": "no-cache",
    "TE": "Trailers",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"
    }

    data = {
  "asset": "USDT",
  "fiat": "RUB",
  "merchantCheck": None,
  "page": 1,
  "payTypes": ["RosBank"],
  "publisherType": "merchant",
  "rows": 1,
  "tradeType": "SELL"
    }


    r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', headers=headers, json=data)
    kur = r.text
    index1 = find_nth(kur, 'price', 3)
   # index = find_nth(kur, 'minSingleTransAmount', 1)
   # minvalue = kur[index+23:index+33] 
   # if minvalue.find('"') == -1 :
    #    redminvaluet =float(minvalue) 
   #     print(float(minvalue))
    #else:
    #    val=minvalue.split('"',1)[0]
   #     redminvalues = float(val)
    #    print(redminvaluet)
    redprices=(float(kur[index1+8:index1+13]))
    return redprices

# %%
def greenTink():
    pricet = [0 for i in range(10)]
    volumet = [0 for i in range(10)]
    headers = {
        "Accept": "*/*",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
        "Cache-Control": "no-cache",
        "Connection": "keep-alive",
        "Content-Length": "123",
        "content-type": "application/json",
        "Host": "p2p.binance.com",
        "Origin": "https://p2p.binance.com",
        "Pragma": "no-cache",
        "TE": "Trailers",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"
        }

    data = {
      "asset": "USDT",
      "fiat": "RUB",
      "merchantCheck": False,
      "page": 1,
      "payTypes": ["Tinkoff"],
      "publisherType": None,
      "rows": 20,
      "tradeType": "BUY"
        }


    r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', headers=headers, json=data)
    kur = r.text
    i = 1
    while i <10:
        
        try: 
            index0 = find_nth(kur, 'price', 3)
            pricet[0] = float(kur[index0+8:index0+13])
            index1 = find_nth(kur, 'price', 3+4*i)
            pricet[i] = float(kur[index1+8:index1+13])
        except ValueError:
            pass
        
        i+=1
    j=1
    while j<=10:
        index = find_nth(kur, 'minSingleTransAmount', j)
        minvalue = kur[index+23:index+33] 
        if minvalue.find('"') == -1 :
            try: 
                volumet[j-1] = float(minvalue)
            except ValueError:
                pass
        else:
            try:
                val=minvalue.split('"',1)[0]
                volumet[j-1] =float(val) 
            except ValueError:
                pass
        j+=1
#print(float(kur[index1+8:index1+13]))
    price =list(pricet)
    volume = list(volumet)
    return (price, volume)

# %%
usr_vol = input()
profit1 = 0
while(1):
    redprices = RedSber()
    redpricet = RedTink()
    redpricer = RedRaif()
    volumet=greenTink()
    i=0
    while i<len(volumet[0]):
        minprice=min(redprices,redpricet,redpricer)
        if (minprice==redprices):
            if volumet[1][i] >=150000:
                profit=float(usr_vol)/minprice*volumet[0][i]-float(usr_vol)-float(usr_vol)*0.001*2 
                if profit > profit1:
                    telegram_send.send(messages=["Sber: "+str(profit)],conf='conf.txt')
                    profit1 = profit
        if (minprice==redpricet):
            if volumet[1][i] >=150000:
                profit=float(usr_vol)/minprice*pvolumet[0][i]-float(usr_vol)-float(usr_vol)*0.001*2 
                if profit > profit1:
                    telegram_send.send(messages=["Tink: "+str(profit)],conf='conf.txt')
                    profit1 = profit
        if (minprice==redpricer):
            if volumet[1][i] >=150000:
                profit=float(usr_vol)/minprice*volumet[0][i]-float(usr_vol)-float(usr_vol)*0.001*2 
                if profit > profit1:
                    telegram_send.send(messages=["Raif: "+str(profit)],conf='conf.txt')
                    profit1 = profit
        i+=1
